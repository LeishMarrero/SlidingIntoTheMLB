# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.model_selection import train_test_split
import rfpimp
from sklearn.metrics import mean_absolute_error as mae
import seaborn as sns

# %%
df = pd.read_csv(Path('Joined_stats.csv'))
df.head()
# Out:
#     playerID  yearID nameFirst   nameLast  Age  Height_Inches  weight bats  \
# 0  suareeu01    2019   Eugenio     Suarez   32             71     213    R
# 1  perezsa02    2021  Salvador      Perez   33             75     255    R
# 2  guerrvl02    2021  Vladimir   Guerrero   24             74     240    R
# 3  solerjo01    2019     Jorge      Soler   31             76     235    R
# 4  bellico01    2019      Cody  Bellinger   28             76     203    L
#
#    stint teamID  ...  RBI  SB  CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0      1    CIN  ...  103   3   2  70  189    4   11   0   6    12
# 1      1    KCA  ...  121   1   0  28  170    4   13   0   4    14
# 2      1    TOR  ...  111   4   1  86  110    7    6   0   2    20
# 3      1    KCA  ...  117   3   1  73  178    3   10   0   4    16
# 4      1    LAN  ...  115  15   5  95  108   21    3   0   4    10
#
# [5 rows x 28 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['bats'] = le.fit_transform(df['bats'])
df.head()
# Out:
#     playerID  yearID nameFirst   nameLast  Age  Height_Inches  weight  bats  \
# 0  suareeu01    2019   Eugenio     Suarez   32             71     213     2
# 1  perezsa02    2021  Salvador      Perez   33             75     255     2
# 2  guerrvl02    2021  Vladimir   Guerrero   24             74     240     2
# 3  solerjo01    2019     Jorge      Soler   31             76     235     2
# 4  bellico01    2019      Cody  Bellinger   28             76     203     1
#
#    stint teamID  ...  RBI  SB  CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0      1    CIN  ...  103   3   2  70  189    4   11   0   6    12
# 1      1    KCA  ...  121   1   0  28  170    4   13   0   4    14
# 2      1    TOR  ...  111   4   1  86  110    7    6   0   2    20
# 3      1    KCA  ...  117   3   1  73  178    3   10   0   4    16
# 4      1    LAN  ...  115  15   5  95  108   21    3   0   4    10
#
# [5 rows x 28 columns]

# %%
X = df.Age.values.reshape(-1, 1)
y = df.HR

# %%
model = LinearRegression()

# %%
# Training the model
lm = model.fit(X, y)

# %%
y_pred = lm.predict(X)

# %%
# Print the intercept
print(lm.intercept_)
# Out:
# 5.399498209302305

# %%
# Print the coefficients from model
print(lm.coef_)
# Out:
# [0.12353594]

# %%
r2 = model.score(X, y)
r2
# Out:
# 0.002755078538834943

# %%
plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(X, y_pred, color='red', label='Regression model')
ax.scatter(X, y, edgecolor='k', facecolor='grey', alpha=0.7, label='Sample data')
ax.set_ylabel('Homeruns', fontsize=14)
ax.set_xlabel('Age', fontsize=14)
ax.legend(facecolor='white', fontsize=11)
ax.set_title('$R^2= %.2f$' % r2, fontsize=18)

fig.tight_layout()

# %%
X1 = df.Height_Inches.values.reshape(-1, 1)
y = df.HR

# %%
model = LinearRegression()

# %%
# Training the model
lm = model.fit(X1, y)
y_pred = lm.predict(X1)

# %%
# Print the intercept
print(lm.intercept_)
# Print the coefficients from model
print(lm.coef_)
# Out:
# -30.789274278402633
# [0.54859486]

# %%
r2 = model.score(X1, y)
r2
# Out:
# 0.017478869898499005

# %%
plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(X1, y_pred, color='red', label='Regression model')
ax.scatter(X1, y, edgecolor='k', facecolor='grey', alpha=0.7, label='Sample data')
ax.set_ylabel('Homeruns', fontsize=14)
ax.set_xlabel('Height (in)', fontsize=14)
ax.legend(facecolor='white', fontsize=11)
ax.set_title('$R^2= %.2f$' % r2, fontsize=18)

fig.tight_layout()

# %%
X2 = df.weight.values.reshape(-1, 1)
y = df.HR

# %%
model = LinearRegression()

# %%
# Training the model
lm = model.fit(X2, y)
y_pred = lm.predict(X2)

# %%
# Print the intercept
print(lm.intercept_)
# Print the coefficients from model
print(lm.coef_)
# Out:
# -7.479701575166285
# [0.07964074]

# %%
r2 = model.score(X2, y)
r2
# Out:
# 0.03192348026902636

# %%
plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(X2, y_pred, color='red', label='Regression model')
ax.scatter(X2, y, edgecolor='k', facecolor='grey', alpha=0.7, label='Sample data')
ax.set_ylabel('Homeruns', fontsize=14)
ax.set_xlabel('Weight', fontsize=14)
ax.legend(facecolor='white', fontsize=11)
ax.set_title('$R^2= %.2f$' % r2, fontsize=18)

fig.tight_layout()

# %%
X3 = df.bats.values.reshape(-1, 1)
y = df.HR

# %%
model = LinearRegression()

# %%
# Training the model
lm = model.fit(X3, y)
y_pred = lm.predict(X3)

# %%
# Print the intercept
print(lm.intercept_)
# Print the coefficients from model
print(lm.coef_)
# Out:
# 8.390082307729038
# [0.57851996]

# %%
r2 = model.score(X3, y)
r2
# Out:
# 0.0019295105422425518

# %%
plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(X3, y_pred, color='red', label='Regression model')
ax.scatter(X3, y, edgecolor='k', facecolor='grey', alpha=0.7, label='Sample data')
ax.set_ylabel('Homeruns', fontsize=14)
ax.set_xlabel('Bats', fontsize=14)
ax.legend(facecolor='white', fontsize=11)
ax.set_title('$R^2= %.2f$' % r2, fontsize=18)

fig.tight_layout()

# %%
X4 = df.H.values.reshape(-1, 1)
y = df.HR

# %%
model = LinearRegression()

# %%
# Training the model
lm = model.fit(X4, y)
y_pred = lm.predict(X4)

# %%
# Print the intercept
print(lm.intercept_)
# Print the coefficients from model
print(lm.coef_)
# Out:
# 0.09817142556707203
# [0.15249958]

# %%
r2 = model.score(X4, y)
r2
# Out:
# 0.6298418674561759

# %%
plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(X4, y_pred, color='red', label='Regression model')
ax.scatter(X4, y, edgecolor='k', facecolor='grey', alpha=0.7, label='Sample data')
ax.set_ylabel('Homeruns', fontsize=14)
ax.set_xlabel('Hits', fontsize=14)
ax.legend(facecolor='white', fontsize=11)
ax.set_title('$R^2= %.2f$' % r2, fontsize=18)

fig.tight_layout()
